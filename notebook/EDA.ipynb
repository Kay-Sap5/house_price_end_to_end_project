# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("House_Price.csv")

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.drop(columns = ["dist1",'dist2','dist3','dist4','bus_ter'] , inplace = True)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     0.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     0.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     0.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     0.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks
# 0       4.98     YES       5.480      11.1920     River        23  0.049347
# 1       9.14      NO       7.332      12.1728      Lake        42  0.046146
# 2       4.03      NO       7.394     101.1200       NaN        38  0.045764
# 3       2.94     YES       9.268      11.2672      Lake        45  0.047151
# 4       5.33      NO       8.824      11.2896      Lake        55  0.039474

# %%
temp = df.copy()

# %%
temp.isnull().sum()
# Out:
# price            0
# crime_rate       0
# resid_area       0
# air_qual         0
# room_num         0
# age              0
# teachers         0
# poor_prop        0
# airport          0
# n_hos_beds       8
# n_hot_rooms      0
# waterbody      155
# rainfall         0
# parks            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2      24.7
# 1     21.6     0.02731       37.07     0.469     6.421  78.9      22.2
# 2     34.7     0.02729       37.07     0.469     7.185  61.1      22.2
# 3     33.4     0.03237       32.18     0.458     6.998  45.8      21.3
# 4     36.2     0.06905       32.18     0.458     7.147  54.2      21.3
# ..     ...         ...         ...       ...       ...   ...       ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1      19.0
# 502   20.6     0.04527       41.93     0.573     6.120  76.7      19.0
# 503   23.9     0.06076       41.93     0.573     6.976  91.0      19.0
# 504   22.0     0.10959       41.93     0.573     6.794  89.3      19.0
# 505   19.0     0.04741       41.93     0.573     6.030  80.8      19.0
#
#      poor_prop airport  n_hos_beds  n_hot_rooms       waterbody  rainfall  \
# ...

# %%
sns.scatterplot(x = df['crime_rate'],y = df['price'])
# Out:
# <Axes: xlabel='crime_rate', ylabel='price'>

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2      24.7
# 1   21.6     0.02731       37.07     0.469     6.421  78.9      22.2
# 2   34.7     0.02729       37.07     0.469     7.185  61.1      22.2
# 3   33.4     0.03237       32.18     0.458     6.998  45.8      21.3
# 4   36.2     0.06905       32.18     0.458     7.147  54.2      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks
# 0       4.98     YES       5.480      11.1920     River        23  0.049347
# 1       9.14      NO       7.332      12.1728      Lake        42  0.046146
# 2       4.03      NO       7.394     101.1200       NaN        38  0.045764
# 3       2.94     YES       9.268      11.2672      Lake        45  0.047151
# 4       5.33      NO       8.824      11.2896      Lake        55  0.039474

# %%
cat_feature = df.select_dtypes("O").columns
num_feature = df.select_dtypes(exclude="O").columns

# %%
num_feature
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall',
#        'parks'],
#       dtype='object')

# %%
for i in num_feature:
    plt.subplot(1,2,1)
    plt.title(f"{i} x Price")
    sns.scatterplot(x = df[i] , y = df['price'])
    plt.subplot(1,2,2)
    sns.boxplot(df[i])
    plt.show()

# %%
df['n_hot_rooms'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
for i in cat_feature:
    print(f"{i} has unique value === > {df[i].unique()}")
# Out:
# airport has unique value === > ['YES' 'NO']
# waterbody has unique value === > ['River' 'Lake' nan 'Lake and River']

# %%
df['waterbody'].isnull().sum()
# Out:
# np.int64(155)

# %%
temp[temp['waterbody'].isnull()]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num    age  teachers  \
# 2     34.7     0.02729       37.07     0.469     7.185   61.1      22.2
# 5     28.7     0.02985       32.18     0.458     6.430   58.7      21.3
# 8     16.5     0.21124       37.87     0.524     5.631  100.0      24.8
# 13    20.4     0.62976       38.14     0.538     5.949   61.8      19.0
# 14    18.2     0.63796       38.14     0.538     6.096   84.5      19.0
# ..     ...         ...         ...       ...       ...    ...       ...
# 489    7.0     0.18337       57.74     0.609     5.414   98.3      19.9
# 491   13.6     0.10574       57.74     0.609     5.983   98.8      19.9
# 503   23.9     0.06076       41.93     0.573     6.976   91.0      19.0
# 504   22.0     0.10959       41.93     0.573     6.794   89.3      19.0
# 505   19.0     0.04741       41.93     0.573     6.030   80.8      19.0
#
#      poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks
# ...

# %%
df.to_csv("data.csv" , index=False , header = True)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 train_set , test_set = train_test_split(df , test_size = 0.2 , random_state = 30)
#
# NameError: name 'train_test_split' is not defined
